# %%
import pandas as pd

# %%
data = pd.read_csv("credit-data.csv")

# %%
data_key = pd.read_excel("Data Dictionary.xls")

# %%
data_key = data_key.iloc[:, 0:3].T.reset_index(drop=True)

# %%
data_key
# Out:
#                                                   0   \
# 0                                   SeriousDlqin2yrs
# 1  Person experienced 90 days past due delinquenc...
# 2                                                Y/N
#
#                                                   1   \
# 0               RevolvingUtilizationOfUnsecuredLines
# 1  Total balance on credit cards and personal lin...
# 2                                         percentage
#
#                          2   \
# 0                       age
# 1  Age of borrower in years
# 2                   integer
#
#                                                   3                        4   \
# 0               NumberOfTime30-59DaysPastDueNotWorse                  zipcode
# 1  Number of times borrower has been 30-59 days p...  zipcode of the borrower
# 2                                            integer          interget/string
#
#                                                   5               6   \
# 0                                          DebtRatio   MonthlyIncome
# 1  Monthly debt payments, alimony,living costs di...  Monthly income
# 2                                         percentage            real
#
#                                                   7   \
# 0                    NumberOfOpenCreditLinesAndLoans
# 1  Number of Open loans (installment like car loa...
# 2                                            integer
#
#                                                   8   \
# 0                            NumberOfTimes90DaysLate
# 1  Number of times borrower has been 90 days or m...
# 2                                            integer
#
#                                                   9   \
# 0                       NumberRealEstateLoansOrLines
# 1  Number of mortgage and real estate loans inclu...
# 2                                            integer
#
#                                                   10  \
# 0               NumberOfTime60-89DaysPastDueNotWorse
# 1  Number of times borrower has been 60-89 days p...
# 2                                            integer
#
#                                                   11
# 0                                 NumberOfDependents
# 1  Number of dependents in family excluding thems...
# 2                                            integer

# %%
data_key.rename(columns = data_key.loc[0], inplace = True)

# %%
data_key = data_key.drop([0])

# %%
data_updated = pd.concat([data, data_key])

# %%
data_updated.reset_index(drop = True, inplace = True)

# %%
df = pd.concat([data_updated.iloc[41016:41018,:], data_updated.drop([41016,41017], axis=0)], axis=0)

# %%
df = df.reset_index(drop = True)

# %%
df.head()
# Out:
#                                            DebtRatio   MonthlyIncome  \
# 0  Monthly debt payments, alimony,living costs di...  Monthly income
# 1                                         percentage            real
# 2                                                505               0
# 3                                           0.459565           15666
# 4                                          0.0145204            4200
#
#                                   NumberOfDependents  \
# 0  Number of dependents in family excluding thems...
# 1                                            integer
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                      NumberOfOpenCreditLinesAndLoans  \
# 0  Number of Open loans (installment like car loa...
# 1                                            integer
# 2                                                  2
# 3                                                  7
# 4                                                  5
#
#                 NumberOfTime30-59DaysPastDueNotWorse  \
# 0  Number of times borrower has been 30-59 days p...
# 1                                            integer
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                 NumberOfTime60-89DaysPastDueNotWorse  \
# 0  Number of times borrower has been 60-89 days p...
# 1                                            integer
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                              NumberOfTimes90DaysLate  \
# 0  Number of times borrower has been 90 days or m...
# 1                                            integer
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                         NumberRealEstateLoansOrLines  PersonID  \
# 0  Number of mortgage and real estate loans inclu...       NaN
# 1                                            integer       NaN
# 2                                                  0   98976.0
# 3                                                  2   98991.0
# 4                                                  0   99012.0
#
#                 RevolvingUtilizationOfUnsecuredLines  \
# 0  Total balance on credit cards and personal lin...
# 1                                         percentage
# 2                                                  1
# 3                                           0.547745
# 4                                          0.0442802
#
#                                     SeriousDlqin2yrs  \
# 0  Person experienced 90 days past due delinquenc...
# 1                                                Y/N
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                         age                  zipcode
# 0  Age of borrower in years  zipcode of the borrower
# 1                   integer          interget/string
# 2                        55                    60601
# 3                        71                    60601
# 4                        51                    60601
